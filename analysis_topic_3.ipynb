# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB 325.1 kB/s eta 0:00:30
#    ---------------------------------------- 0.0/9.8 MB 325.1 kB/s eta 0:00:30
#    ---------------------------------------- 0.0/9.8 MB 245.8 kB/s eta 0:00:40
#    ---------------------------------------- 0.0/9.8 MB 245.8 kB/s eta 0:00:40
#    ---------------------------------------- 0.0/9.8 MB 245.8 kB/s eta 0:00:40
#    ---------------------------------------- 0.0/9.8 MB 245.8 kB/s eta 0:00:40
#    ---------------------------------------- 0.0/9.8 MB 245.8 kB/s eta 0:00:40
#    ---------------------------------------- 0.0/9.8 MB 245.8 kB/s eta 0:00:40
#    ---------------------------------------- 0.0/9.8 MB 245.8 kB/s eta 0:00:40
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('users.csv')
print(df.head())
# Out:
#   user_id         name  age                       preferred_genres  \
# 0    U001    Uma Brown   17        Horror|Sci-Fi|Documentary|Drama
# 1    U002  Diana Perez   21  Thriller|Action|Documentary|Animation
# 2    U003   Hannah Lee   54                     Documentary|Sci-Fi
# 3    U004    Uma Perez   42                       Animation|Horror
# 4    U005  Yara Garcia   60                  Romance|Horror|Comedy
#
#   subscription_plan
# 0           Premium
# 1             Basic
# 2           Premium
# 3             Basic
# 4             Basic

# %%
import pandas as pd

df = pd.read_csv('movies.csv')  
print(df.head())
# Out:
#   movie_id                     title     genre           director  \
# 0     M001                 Inception    Sci-Fi  Christopher Nolan
# 1     M002                    Barbie    Comedy       Greta Gerwig
# 2     M003         Avengers: Endgame    Action  Christopher Nolan
# 3     M004                  Parasite  Thriller       Bong Joon-ho
# 4     M005  The Grand Budapest Hotel    Comedy       Wes Anderson
#
#    release_year  avg_rating  duration_min language  \
# 0          2010         6.6           112  English
# 1          2023         7.2           161  English
# 2          2019         7.9           151  English
# 3          2019         6.8           137  English
# 4          2014         8.7           173  English
#
#                           tags
# 0  award-winning|based-on-book
# 1  based-on-book|award-winning
# 2            indie|blockbuster
# 3          cult-classic|sequel
# 4   cult-classic|based-on-book

# %%
df = pd.read_csv('viewing_history.csv')
print(df.head())
# Out:
#   history_id user_id movie_id              title   genre           director  \
# 0      H0001    U001     M008       Interstellar  Sci-Fi  Christopher Nolan
# 1      H0002    U001     M006               Dune  Sci-Fi   Denis Villeneuve
# 2      H0003    U001     M018             Avatar  Sci-Fi      James Cameron
# 3      H0004    U001     M003  Avengers: Endgame  Action  Christopher Nolan
# 4      H0005    U001     M029       The Irishman   Drama    Martin Scorsese
#
#    user_rating  watch_date completed    device
# 0          4.5  2023-08-19        No    Laptop
# 1          3.8  2023-01-17       Yes    Tablet
# 2          4.5  2023-02-06       Yes    Mobile
# 3          1.4  2023-08-06       Yes    Mobile
# 4          4.7  2023-05-17       Yes  Smart TV
